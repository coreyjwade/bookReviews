# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Amazon_Data_Frame.csv', nrows=10000)

# %%
import ast
myList = np.array(df.helpful.apply(lambda row: ast.literal_eval(row)).tolist())
df['helpfulVotes'] = myList[:,0]
df['totalVotes'] = myList[:,1]
df.head()
# Out:
#    Unnamed: 0        asin helpful  overall  \
# 0           0  000100039X  [0, 0]      5.0
# 1           1  000100039X  [0, 2]      5.0
# 2           2  000100039X  [0, 0]      5.0
# 3           3  000100039X  [0, 0]      5.0
# 4           4  000100039X  [7, 9]      5.0
#
#                                           reviewText   reviewTime  \
# 0  Spiritually and mentally inspiring! A book tha...  12 16, 2012
# 1  This is one my must have books. It is a master...  12 11, 2003
# 2  This book provides a reflection that you can a...  01 18, 2014
# 3  I first read THE PROPHET in college back in th...  09 27, 2011
# 4  A timeless classic.  It is a very demanding an...   10 7, 2002
#
#               reviewerID                                     reviewerName  \
# 0  A10000012B7CGYKOMPQ4L                                             Adam
# 1         A2S166WSCFIFP5  adead_poet@hotmail.com "adead_poet@hotmail.com"
# 2         A1BM81XB4QHOA3                      Ahoro Blethends "Seriously"
# ...

# %%
df['freq'] = df.groupby('asin')['asin'].transform('count')

# %%
df.head()
# Out:
#    Unnamed: 0        asin helpful  overall  \
# 0           0  000100039X  [0, 0]      5.0
# 1           1  000100039X  [0, 2]      5.0
# 2           2  000100039X  [0, 0]      5.0
# 3           3  000100039X  [0, 0]      5.0
# 4           4  000100039X  [7, 9]      5.0
#
#                                           reviewText   reviewTime  \
# 0  Spiritually and mentally inspiring! A book tha...  12 16, 2012
# 1  This is one my must have books. It is a master...  12 11, 2003
# 2  This book provides a reflection that you can a...  01 18, 2014
# 3  I first read THE PROPHET in college back in th...  09 27, 2011
# 4  A timeless classic.  It is a very demanding an...   10 7, 2002
#
#               reviewerID                                     reviewerName  \
# 0  A10000012B7CGYKOMPQ4L                                             Adam
# 1         A2S166WSCFIFP5  adead_poet@hotmail.com "adead_poet@hotmail.com"
# 2         A1BM81XB4QHOA3                      Ahoro Blethends "Seriously"
# ...

# %%
df = df.set_index(['reviewerID', 'asin'])

# %%
df.head()
# Out:
#                                   Unnamed: 0 helpful  overall  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X           0  [0, 0]      5.0
# A2S166WSCFIFP5        000100039X           1  [0, 2]      5.0
# A1BM81XB4QHOA3        000100039X           2  [0, 0]      5.0
# A1MOSTXNIO5MPJ        000100039X           3  [0, 0]      5.0
# A2XQ5LZHTD4AFT        000100039X           4  [7, 9]      5.0
#
#                                                                          reviewText  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X  Spiritually and mentally inspiring! A book tha...
# A2S166WSCFIFP5        000100039X  This is one my must have books. It is a master...
# A1BM81XB4QHOA3        000100039X  This book provides a reflection that you can a...
# A1MOSTXNIO5MPJ        000100039X  I first read THE PROPHET in college back in th...
# A2XQ5LZHTD4AFT        000100039X  A timeless classic.  It is a very demanding an...
#
# ...

# %%
del df['Unnamed: 0']

# %%
df['helpfulSum'] = df.groupby('reviewerID')['helpfulVotes'].transform('sum')

# %%
df[50:100]
# Out:
#                             helpful  overall  \
# reviewerID     asin
# APW96HJ7GYRJH  000100039X    [3, 3]      5.0
# A2QZFUQ8ME1KYS 000100039X    [0, 0]      5.0
# AW1Z7GYIBWB4K  000100039X    [0, 0]      5.0
# AMRZ5G7HF7I03  000100039X    [4, 4]      5.0
# A34HCSZJXZLPC  000100039X    [3, 5]      5.0
# A3QZI8VT0VWUEX 000100039X    [0, 0]      5.0
# AI9CMLQWH9KRP  000100039X    [2, 4]      5.0
# A2NHD7LUXVGTD3 000100039X    [1, 1]      5.0
# A1K1JW1C5CUSUZ 000100039X    [3, 4]      5.0
# ADS5APY1NKTL4  000100039X    [1, 1]      5.0
# A12W8NRSYR593I 000100039X    [0, 0]      5.0
# A3A0ZK5GTHSCUV 000100039X    [4, 4]      5.0
# A38AAPXSJN4C5G 000100039X    [0, 0]      5.0
# AA6C78DHRK962  000100039X    [0, 0]      5.0
# A263JC385S09O8 000100039X    [0, 0]      5.0
# AFY0BT42DDYZV  000100039X    [5, 6]      5.0
# A2TBX999AZ6Z7U 000100039X    [0, 0]      5.0
# A11TYILTAFKPR3 000100039X    [4, 4]      5.0
# A308E1C7MU3462 000100039X    [0, 0]      5.0
# ...

# %%
df['totalSum'] = df.groupby('reviewerID')['totalVotes'].transform('sum')

# %%
df[50:100]
# Out:
#                             helpful  overall  \
# reviewerID     asin
# APW96HJ7GYRJH  000100039X    [3, 3]      5.0
# A2QZFUQ8ME1KYS 000100039X    [0, 0]      5.0
# AW1Z7GYIBWB4K  000100039X    [0, 0]      5.0
# AMRZ5G7HF7I03  000100039X    [4, 4]      5.0
# A34HCSZJXZLPC  000100039X    [3, 5]      5.0
# A3QZI8VT0VWUEX 000100039X    [0, 0]      5.0
# AI9CMLQWH9KRP  000100039X    [2, 4]      5.0
# A2NHD7LUXVGTD3 000100039X    [1, 1]      5.0
# A1K1JW1C5CUSUZ 000100039X    [3, 4]      5.0
# ADS5APY1NKTL4  000100039X    [1, 1]      5.0
# A12W8NRSYR593I 000100039X    [0, 0]      5.0
# A3A0ZK5GTHSCUV 000100039X    [4, 4]      5.0
# A38AAPXSJN4C5G 000100039X    [0, 0]      5.0
# AA6C78DHRK962  000100039X    [0, 0]      5.0
# A263JC385S09O8 000100039X    [0, 0]      5.0
# AFY0BT42DDYZV  000100039X    [5, 6]      5.0
# A2TBX999AZ6Z7U 000100039X    [0, 0]      5.0
# A11TYILTAFKPR3 000100039X    [4, 4]      5.0
# A308E1C7MU3462 000100039X    [0, 0]      5.0
# ...

# %%
del df['helpful']

# %%
df.columns = ['Stars', 'Text', 'Time', 'Name_Reviewer', 'Summary', 'Unix_Time', 'Helpful_Votes', 'Total_Votes', 'Review_Count_Book', 'Helpful_Sum_User', 'Total_Sum_User']
df.head()
# Out:
#                                   Stars  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X    5.0
# A2S166WSCFIFP5        000100039X    5.0
# A1BM81XB4QHOA3        000100039X    5.0
# A1MOSTXNIO5MPJ        000100039X    5.0
# A2XQ5LZHTD4AFT        000100039X    5.0
#
#                                                                                Text  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X  Spiritually and mentally inspiring! A book tha...
# A2S166WSCFIFP5        000100039X  This is one my must have books. It is a master...
# A1BM81XB4QHOA3        000100039X  This book provides a reflection that you can a...
# A1MOSTXNIO5MPJ        000100039X  I first read THE PROPHET in college back in th...
# A2XQ5LZHTD4AFT        000100039X  A timeless classic.  It is a very demanding an...
#
#                                          Time  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X  12 16, 2012
# ...

# %%
df['Helpful_Sum_Book'] = df.groupby('asin')['Helpful_Votes'].transform('sum')

# %%
df.tail()
# Out:
#                            Stars  \
# reviewerID     asin
# A36MDVJ59IZNXH 0006514006    5.0
# A10VOEBL5S337W 0006514006    5.0
# A3HBE3VAKQ7RYF 0006514006    4.0
# A2I5HGFRL5GVQJ 0006514006    4.0
# A83MKA85YHNIX  0006514006    1.0
#
#                                                                         Text  \
# reviewerID     asin
# A36MDVJ59IZNXH 0006514006  this was a great book.  I did not like the Con...
# A10VOEBL5S337W 0006514006  The thing you must realize about this book is ...
# A3HBE3VAKQ7RYF 0006514006  The Other Boleyn girl was a highly engrossing ...
# A2I5HGFRL5GVQJ 0006514006  Last week I finished reading The Other Boleyn ...
# A83MKA85YHNIX  0006514006  I confess that I used to be a consistent reade...
#
#                                   Time  \
# reviewerID     asin
# A36MDVJ59IZNXH 0006514006   10 6, 2007
# A10VOEBL5S337W 0006514006   09 3, 2012
# A3HBE3VAKQ7RYF 0006514006  08 17, 2011
# A2I5HGFRL5GVQJ 0006514006  09 13, 2008
# ...

# %%
df['Total_Sum_Book'] = df.groupby('asin')['Total_Votes'].transform('sum')

# %%
df.head()
# Out:
#                                   Stars  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X    5.0
# A2S166WSCFIFP5        000100039X    5.0
# A1BM81XB4QHOA3        000100039X    5.0
# A1MOSTXNIO5MPJ        000100039X    5.0
# A2XQ5LZHTD4AFT        000100039X    5.0
#
#                                                                                Text  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X  Spiritually and mentally inspiring! A book tha...
# A2S166WSCFIFP5        000100039X  This is one my must have books. It is a master...
# A1BM81XB4QHOA3        000100039X  This book provides a reflection that you can a...
# A1MOSTXNIO5MPJ        000100039X  I first read THE PROPHET in college back in th...
# A2XQ5LZHTD4AFT        000100039X  A timeless classic.  It is a very demanding an...
#
#                                          Time  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X  12 16, 2012
# ...

# %%
df['Helpful_Percentage']=(df['Helpful_Sum_User']/(df['Total_Sum_User'])).fillna(0)
df.head()
# Out:
#                                   Stars  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X    5.0
# A2S166WSCFIFP5        000100039X    5.0
# A1BM81XB4QHOA3        000100039X    5.0
# A1MOSTXNIO5MPJ        000100039X    5.0
# A2XQ5LZHTD4AFT        000100039X    5.0
#
#                                                                                Text  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X  Spiritually and mentally inspiring! A book tha...
# A2S166WSCFIFP5        000100039X  This is one my must have books. It is a master...
# A1BM81XB4QHOA3        000100039X  This book provides a reflection that you can a...
# A1MOSTXNIO5MPJ        000100039X  I first read THE PROPHET in college back in th...
# A2XQ5LZHTD4AFT        000100039X  A timeless classic.  It is a very demanding an...
#
#                                          Time  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X  12 16, 2012
# ...

# %%
df.Helpful_Votes.max()
# Out:
# 1515

# %%
df.describe()
# Out:
#              Stars     Unix_Time  Helpful_Votes   Total_Votes  \
# count  10000.00000  1.000000e+04   10000.000000  10000.000000
# mean       4.15840  1.270938e+09       4.210300      6.207200
# std        1.16329  1.264726e+08      29.394484     32.772108
# min        1.00000  8.714304e+08       0.000000      0.000000
# 25%        4.00000  1.196813e+09       0.000000      0.000000
# 50%        5.00000  1.315181e+09       1.000000      1.000000
# 75%        5.00000  1.367626e+09       3.000000      5.000000
# max        5.00000  1.405123e+09    1515.000000   1581.000000
#
#        Review_Count_Book  Helpful_Sum_User  Total_Sum_User  Helpful_Sum_Book  \
# count        10000.00000      10000.000000    10000.000000      10000.000000
# mean          1234.64140          5.957000        8.398100       5558.145500
# std           1173.12622         35.039933       39.208049       5886.615298
# min              5.00000          0.000000        0.000000          2.000000
# ...

# %%
df_reduced = df[df['Total_Votes']!=0]

# %%
helpfulMean = df_reduced.Helpful_Votes.mean()

# %%
df['Helpful_Above_Mean']=df['Helpful_Sum_User']-helpfulMean

# %%
helpfulPercentage = 0.7426197720523914
df['Helpful_Above_Mean'] = df['Helpful_Sum_User']-df['Total_Sum_User']*helpfulPercentage

# %%
df_reduced = df[df['Total_Votes']!=0]
df_reduced.describe()
# Out:
#              Stars     Unix_Time  Helpful_Votes  Total_Votes  \
# count  7166.000000  7.166000e+03    7166.000000  7166.000000
# mean      4.030421  1.246764e+09       5.875384     8.662015
# std       1.258682  1.294223e+08      34.583329    38.438941
# min       1.000000  8.714304e+08       0.000000     1.000000
# 25%       3.000000  1.173312e+09       1.000000     1.000000
# 50%       5.000000  1.303085e+09       1.000000     3.000000
# 75%       5.000000  1.356739e+09       4.000000     8.000000
# max       5.000000  1.404950e+09    1515.000000  1581.000000
#
#        Review_Count_Book  Helpful_Sum_User  Total_Sum_User  Helpful_Sum_Book  \
# count        7166.000000       7166.000000     7166.000000       7166.000000
# mean         1359.947809          8.105638       11.456042       6374.780631
# std          1163.180822         41.101225       45.851777       6066.442193
# min             5.000000          0.000000        1.000000          2.000000
# ...

# %%
df.head()
# Out:
#                                   Stars  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X    5.0
# A2S166WSCFIFP5        000100039X    5.0
# A1BM81XB4QHOA3        000100039X    5.0
# A1MOSTXNIO5MPJ        000100039X    5.0
# A2XQ5LZHTD4AFT        000100039X    5.0
#
#                                                                                Text  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X  Spiritually and mentally inspiring! A book tha...
# A2S166WSCFIFP5        000100039X  This is one my must have books. It is a master...
# A1BM81XB4QHOA3        000100039X  This book provides a reflection that you can a...
# A1MOSTXNIO5MPJ        000100039X  I first read THE PROPHET in college back in th...
# A2XQ5LZHTD4AFT        000100039X  A timeless classic.  It is a very demanding an...
#
#                                          Time  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X  12 16, 2012
# ...

# %%
df['Helpful_Above_Mean'].quantile(0.9)
# Out:
# 1.2869011397380432

# %%
df['Helpful_Above_Mean'].quantile(0.95)
# Out:
# 2.860703419214129

# %%
df['Helpful_Above_Mean'].quantile(0.98)
# Out:
# 6.464026610480651

# %%
df['Helpful_Above_Mean'].quantile(0.99)
# Out:
# 14.063684421582293

# %%
import math
math.exp(2)
# Out:
# 7.38905609893065

# %%
df['Helpful_Sum_Logistic']=100/(1+100*np.exp(-0.8*df['Helpful_Above_Mean']))-100/101

# %%
df.head()
# Out:
#                                   Stars  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X    5.0
# A2S166WSCFIFP5        000100039X    5.0
# A1BM81XB4QHOA3        000100039X    5.0
# A1MOSTXNIO5MPJ        000100039X    5.0
# A2XQ5LZHTD4AFT        000100039X    5.0
#
#                                                                                Text  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X  Spiritually and mentally inspiring! A book tha...
# A2S166WSCFIFP5        000100039X  This is one my must have books. It is a master...
# A1BM81XB4QHOA3        000100039X  This book provides a reflection that you can a...
# A1MOSTXNIO5MPJ        000100039X  I first read THE PROPHET in college back in th...
# A2XQ5LZHTD4AFT        000100039X  A timeless classic.  It is a very demanding an...
#
#                                          Time  \
# reviewerID            asin
# A10000012B7CGYKOMPQ4L 000100039X  12 16, 2012
# ...

# %%
df.describe()
# Out:
#              Stars     Unix_Time  Helpful_Votes   Total_Votes  \
# count  10000.00000  1.000000e+04   10000.000000  10000.000000
# mean       4.15840  1.270938e+09       4.210300      6.207200
# std        1.16329  1.264726e+08      29.394484     32.772108
# min        1.00000  8.714304e+08       0.000000      0.000000
# 25%        4.00000  1.196813e+09       0.000000      0.000000
# 50%        5.00000  1.315181e+09       1.000000      1.000000
# 75%        5.00000  1.367626e+09       3.000000      5.000000
# max        5.00000  1.405123e+09    1515.000000   1581.000000
#
#        Review_Count_Book  Helpful_Sum_User  Total_Sum_User  Helpful_Sum_Book  \
# count        10000.00000      10000.000000    10000.000000      10000.000000
# mean          1234.64140          5.957000        8.398100       5558.145500
# std           1173.12622         35.039933       39.208049       5886.615298
# min              5.00000          0.000000        0.000000          2.000000
# ...

# %%
df['Helpful_Sum_Logistic'].quantile(0.95)
# Out:
# 7.985585691317021

# %%
df['Helpful_Sum_Logistic'].quantile(0.99)
# Out:
# 98.88011638466959

# %%
df['Helpful_Score']=(df['Helpful_Percentage']*100 + df['Helpful_Sum_Logistic'])/2

# %%
df.describe()
# Out:
#              Stars     Unix_Time  Helpful_Votes   Total_Votes  \
# count  10000.00000  1.000000e+04   10000.000000  10000.000000
# mean       4.15840  1.270938e+09       4.210300      6.207200
# std        1.16329  1.264726e+08      29.394484     32.772108
# min        1.00000  8.714304e+08       0.000000      0.000000
# 25%        4.00000  1.196813e+09       0.000000      0.000000
# 50%        5.00000  1.315181e+09       1.000000      1.000000
# 75%        5.00000  1.367626e+09       3.000000      5.000000
# max        5.00000  1.405123e+09    1515.000000   1581.000000
#
#        Review_Count_Book  Helpful_Sum_User  Total_Sum_User  Helpful_Sum_Book  \
# count        10000.00000      10000.000000    10000.000000      10000.000000
# mean          1234.64140          5.957000        8.398100       5558.145500
# std           1173.12622         35.039933       39.208049       5886.615298
# min              5.00000          0.000000        0.000000          2.000000
# ...

# %%
df['Helpful_Score'].quantile(.9)
# Out:
# 50.248498860190296

# %%
df['Helpful_Score'].quantile(.95)
# Out:
# 51.53241842449505

# %%
df['Helpful_Score'].quantile(.99)
# Out:
# 95.23697821037909

# %%
df['Helpful_Score'].quantile(.998)
# Out:
# 98.05148472097899

# %%
df['Helpful_Sum_All_Reviews'] = df.groupby('reviewerID')['Helpful_Sum_Book'].transform('sum')

# %%
df[90:120]
# Out:
#                            Stars  \
# reviewerID     asin
# A3NU1LBH7RPFHV 000100039X    4.0
# A31WDOV3Q22ANV 000100039X    5.0
# ABFOAYZA2UHD3  000100039X    5.0
# A1XU2UXCTFC9WY 000100039X    4.0
# A2X6GEC6LCDN4S 000100039X    5.0
# AAFLZI7MX9UIG  000100039X    5.0
# A1FQPOYRBTTK1  000100039X    5.0
# A1JBOMEZBH80JU 000100039X    5.0
# A2DFYTW62P25Z  000100039X    5.0
# A2MPRPCAQLTR3L 000100039X    5.0
# A2W6WXEUAVM3E  000100039X    5.0
# A7GT0WQKKDP0V  000100039X    5.0
# ATAPOART4QGVO  000100039X    3.0
# A2052JNVUPRTMT 000100039X    5.0
# ADT39C7GOEAWW  000100039X    4.0
# ASW9FWXSGKV2C  000100039X    5.0
# AGKPTMTR3UX1R  000100039X    5.0
# A1HS49P9TZRGV9 000100039X    5.0
# AMFSDTN7LJ4EM  000100039X    5.0
# A3Q5B6YEMGK4HI 000100039X    5.0
# A2W4TXYV1M7FQ4 000100039X    5.0
# AYZLXLVMJGTJV  000100039X    5.0
# AG74166FELW9U  000100039X    5.0
# A2W53LAQBPR831 000100039X    4.0
# A2ZZHMT58ZMVCZ 000100039X    5.0
# A5K32C2QZN3WL  000100039X    4.0
# ...

# %%
df_reduced = df[df['Total_Votes']!=0]

# %%
df_reduced.head()
# Out:
#                            Stars  \
# reviewerID     asin
# A2S166WSCFIFP5 000100039X    5.0
# A2XQ5LZHTD4AFT 000100039X    5.0
# A19N3FCQCLJYUA 000100039X    5.0
# A3FFNE1DR5SI1W 000100039X    5.0
# A2X4HE21JTAL98 000100039X    5.0
#
#                                                                         Text  \
# reviewerID     asin
# A2S166WSCFIFP5 000100039X  This is one my must have books. It is a master...
# A2XQ5LZHTD4AFT 000100039X  A timeless classic.  It is a very demanding an...
# A19N3FCQCLJYUA 000100039X  I discovered The Prophet fifty years ago in co...
# A3FFNE1DR5SI1W 000100039X  Can't say enough about Kahlil Gibran's work am...
# A2X4HE21JTAL98 000100039X  Anything I've read by Gibran is, in my mind, f...
#
#                                   Time  \
# reviewerID     asin
# A2S166WSCFIFP5 000100039X  12 11, 2003
# A2XQ5LZHTD4AFT 000100039X   10 7, 2002
# A19N3FCQCLJYUA 000100039X  01 23, 2013
# A3FFNE1DR5SI1W 000100039X  06 27, 2012
# ...

# %%
df_reduced['Helpful_Sum_All_Reviews_Reduced'] = df_reduced.groupby('reviewerID')['Helpful_Sum_Book'].transform('sum')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_reduced.head()
# Out:
#                            Stars  \
# reviewerID     asin
# A2S166WSCFIFP5 000100039X    5.0
# A2XQ5LZHTD4AFT 000100039X    5.0
# A19N3FCQCLJYUA 000100039X    5.0
# A3FFNE1DR5SI1W 000100039X    5.0
# A2X4HE21JTAL98 000100039X    5.0
#
#                                                                         Text  \
# reviewerID     asin
# A2S166WSCFIFP5 000100039X  This is one my must have books. It is a master...
# A2XQ5LZHTD4AFT 000100039X  A timeless classic.  It is a very demanding an...
# A19N3FCQCLJYUA 000100039X  I discovered The Prophet fifty years ago in co...
# A3FFNE1DR5SI1W 000100039X  Can't say enough about Kahlil Gibran's work am...
# A2X4HE21JTAL98 000100039X  Anything I've read by Gibran is, in my mind, f...
#
#                                   Time  \
# reviewerID     asin
# A2S166WSCFIFP5 000100039X  12 11, 2003
# A2XQ5LZHTD4AFT 000100039X   10 7, 2002
# A19N3FCQCLJYUA 000100039X  01 23, 2013
# A3FFNE1DR5SI1W 000100039X  06 27, 2012
# ...

# %%
df_reduced['Helpful_Sum_Percentage'] = df_reduced['Helpful_Sum_User']/df_reduced['Helpful_Sum_All_Reviews_Reduced']*100
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_reduced.head()
# Out:
#                            Stars  \
# reviewerID     asin
# A2S166WSCFIFP5 000100039X    5.0
# A2XQ5LZHTD4AFT 000100039X    5.0
# A19N3FCQCLJYUA 000100039X    5.0
# A3FFNE1DR5SI1W 000100039X    5.0
# A2X4HE21JTAL98 000100039X    5.0
#
#                                                                         Text  \
# reviewerID     asin
# A2S166WSCFIFP5 000100039X  This is one my must have books. It is a master...
# A2XQ5LZHTD4AFT 000100039X  A timeless classic.  It is a very demanding an...
# A19N3FCQCLJYUA 000100039X  I discovered The Prophet fifty years ago in co...
# A3FFNE1DR5SI1W 000100039X  Can't say enough about Kahlil Gibran's work am...
# A2X4HE21JTAL98 000100039X  Anything I've read by Gibran is, in my mind, f...
#
#                                   Time  \
# reviewerID     asin
# A2S166WSCFIFP5 000100039X  12 11, 2003
# A2XQ5LZHTD4AFT 000100039X   10 7, 2002
# A19N3FCQCLJYUA 000100039X  01 23, 2013
# A3FFNE1DR5SI1W 000100039X  06 27, 2012
# ...

# %%
df_reduced.describe()
# Out:
#              Stars     Unix_Time  Helpful_Votes  Total_Votes  \
# count  7166.000000  7.166000e+03    7166.000000  7166.000000
# mean      4.030421  1.246764e+09       5.875384     8.662015
# std       1.258682  1.294223e+08      34.583329    38.438941
# min       1.000000  8.714304e+08       0.000000     1.000000
# 25%       3.000000  1.173312e+09       1.000000     1.000000
# 50%       5.000000  1.303085e+09       1.000000     3.000000
# 75%       5.000000  1.356739e+09       4.000000     8.000000
# max       5.000000  1.404950e+09    1515.000000  1581.000000
#
#        Review_Count_Book  Helpful_Sum_User  Total_Sum_User  Helpful_Sum_Book  \
# count        7166.000000       7166.000000     7166.000000       7166.000000
# mean         1359.947809          8.105638       11.456042       6374.780631
# std          1163.180822         41.101225       45.851777       6066.442193
# min             5.000000          0.000000        1.000000          2.000000
# ...

# %%
df_reduced['Helpful_Sum_Percentage'].quantile(0.9)
# Out:
# 4.393305439330543

# %%
df_reduced['Helpful_Sum_Percentage'].quantile(0.95)
# Out:
# 11.093418259023354

# %%
df_reduced['Helpful_Percentage_Logistic']=100/(1+100*np.exp(-0.8*df_reduced['Helpful_Sum_Percentage']))-100/101
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_reduced.describe()
# Out:
#              Stars     Unix_Time  Helpful_Votes  Total_Votes  \
# count  7166.000000  7.166000e+03    7166.000000  7166.000000
# mean      4.030421  1.246764e+09       5.875384     8.662015
# std       1.258682  1.294223e+08      34.583329    38.438941
# min       1.000000  8.714304e+08       0.000000     1.000000
# 25%       3.000000  1.173312e+09       1.000000     1.000000
# 50%       5.000000  1.303085e+09       1.000000     3.000000
# 75%       5.000000  1.356739e+09       4.000000     8.000000
# max       5.000000  1.404950e+09    1515.000000  1581.000000
#
#        Review_Count_Book  Helpful_Sum_User  Total_Sum_User  Helpful_Sum_Book  \
# count        7166.000000       7166.000000     7166.000000       7166.000000
# mean         1359.947809          8.105638       11.456042       6374.780631
# std          1163.180822         41.101225       45.851777       6066.442193
# min             5.000000          0.000000        1.000000          2.000000
# ...

# %%
df_reduced['Helpful_Score_Reduced']=df_reduced['Helpful_Percentage']*100*0.5 + df_reduced['Helpful_Sum_Logistic']*0.35 + df_reduced['Helpful_Percentage_Logistic']*0.15
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dg = df_reduced.groupby('Helpful_Score_Reduced')

# %%
df_check = df_reduced[df_reduced['Helpful_Votes']>10]

# %%
df_check.head()
# Out:
#                            Stars  \
# reviewerID     asin
# A1NPNGWBVD9AK3 000100039X    5.0
# A2052JNVUPRTMT 000100039X    5.0
# AGKPTMTR3UX1R  000100039X    5.0
# A2ZZHMT58ZMVCZ 000100039X    5.0
# A3W43PSHRIG8KV 000100039X    4.0
#
#                                                                         Text  \
# reviewerID     asin
# A1NPNGWBVD9AK3 000100039X  This is one of the first (literary) books I re...
# A2052JNVUPRTMT 000100039X  Gibran gets right down to the bedrock of what ...
# AGKPTMTR3UX1R  000100039X  Kahlil Gibran (1883-1931), the Lebanese-Americ...
# A2ZZHMT58ZMVCZ 000100039X  A prophet has waited twelve years in a coastal...
# A3W43PSHRIG8KV 000100039X  I first became aware of Kahlil Gibran when I r...
#
#                                   Time  \
# reviewerID     asin
# A1NPNGWBVD9AK3 000100039X  06 24, 2000
# A2052JNVUPRTMT 000100039X  11 10, 2000
# AGKPTMTR3UX1R  000100039X   04 9, 2007
# A2ZZHMT58ZMVCZ 000100039X  01 17, 2006
# ...

# %%
df_check[75:85]
# Out:
#                            Stars  \
# reviewerID     asin
# A23GFTVIETX7DS 0002113570    5.0
# A2EQ74Y24BHHIF 0002113570    5.0
# A289FQ3V2BLV77 0002113570    5.0
# ATAPOART4QGVO  0002113570    5.0
# A3PK2LTN51JAMF 0002117088    5.0
# A39BB196X0I2N1 0002117088    5.0
# A3KL4JSUOH8NVF 0002117088    5.0
# A2GHTSBU7IHIBO 0002117088    5.0
# A1115ST6F5CWYP 0002154463    5.0
# A3UKIFTCUBFVDJ 0002154463    2.0
#
#                                                                         Text  \
# reviewerID     asin
# A23GFTVIETX7DS 0002113570  IN THE SHADOW OF MAN, first published in 1971,...
# A2EQ74Y24BHHIF 0002113570  Jane Goodall is a unique undividual whose work...
# A289FQ3V2BLV77 0002113570  The pleasure that Ms. Goodall had placed and r...
# ATAPOART4QGVO  0002113570  Like another reviewer, I'm an anthropology stu...
# A3PK2LTN51JAMF 0002117088  Renoir isn't dead. He lives in this book, and ...
# A39BB196X0I2N1 0002117088  Renoir was far more than one of the world's gr...
# ...

# %%
df_count= df.groupby('reviewerID')[['helpfulVotes', 'totalVotes', 'freq']].agg({'helpfulVotes':'sum', 'totalVotes':
                                                                     'sum', 'asin':'count'})
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)

# %%
df_count.head()
# Out:
#                       helpfulVotes                    totalVotes             \
#                       helpfulVotes totalVotes  freq helpfulVotes totalVotes
# reviewerID
# A03433312WBY334SUIKK8            0          0  2721            0          0
# A04248682NPVFASKSXTAD            0          0  2054            0          0
# A04816858XKO02H7BRNX             1          1  2721            1          1
# A05059033JWCACJUK57F2            0          1  2054            0          1
# A065405511YBV9PD987CA            1          1    77            1          1
#
#                                     asin
#                        freq helpfulVotes totalVotes freq
# reviewerID
# A03433312WBY334SUIKK8  2721            1          1    1
# A04248682NPVFASKSXTAD  2054            1          1    1
# A04816858XKO02H7BRNX   2721            1          1    1
# A05059033JWCACJUK57F2  2054            1          1    1
# A065405511YBV9PD987CA    77            1          1    1

# %%
df_count = pd.DataFrame({'helpfulVotes':df['helpfulVotes'].sum()})
# Out:
#                 helpfulVotes  totalVotes  asin
# reviewerID
# A1AV32Q6I8M1LX            27          32     6
# A1BA72K4VK1UN1            31          50     6
# A1CPSCL93S0VS8            48          56     6
# A1G37DFO8MQW0M            11          14     8
# A1G9FX1KV45N41            18          25     6
# A1IOJE0W1NXOSE            15          23     5
# A1K1JW1C5CUSUZ            26          31     5
# A1L43KWWR05PCS            23          26     9
# A1N1YEMTI9DJ86            42          46     6
# A1NC9AGZOBI0M1            19          23     5
# A1NT7ED5TATUAM            34          40     7
# A1V8NBMG0PDVK1            35          47     6
# A1X8VZWTOG8IS6             7          30    12
# A1ZLFCUF4XX7RZ             6           9     5
# A21Z8FUB9IZI2L            16          23     5
# A2DSXA1E02C86D           134         139     7
# A2F540P3L6P5CL            37          41     7
# A2GBJQ9THOYDAJ            18          20     5
# A2K9FXOFFHVNWG            26          33     5
# ...

# %%
df_book_count = df.groupby('asin').count()

# %%
df_book_count.head()
# Out:
#             Unnamed: 0  helpful  overall  reviewText  reviewTime  reviewerID  \
# asin
# 000100039X         206      206      206         206         206         206
# 0001055178          18       18       18          18          18          18
# 0001473123          16       16       16          16          16          16
# 0001473727           7        7        7           7           7           7
# 0001473905           6        6        6           6           6           6
#
#             reviewerName  summary  unixReviewTime  helpfulVotes  totalVotes
# asin
# 000100039X           206      206             206           206         206
# 0001055178            18       18              18            18          18
# 0001473123            16       16              16            16          16
# 0001473727             7        7               7             7           7
# 0001473905             6        6               6             6           6

# %%
df.head()
# Out:
#    Unnamed: 0        asin helpful  overall  \
# 0           0  000100039X  [0, 0]      5.0
# 1           1  000100039X  [0, 2]      5.0
# 2           2  000100039X  [0, 0]      5.0
# 3           3  000100039X  [0, 0]      5.0
# 4           4  000100039X  [7, 9]      5.0
#
#                                           reviewText   reviewTime  \
# 0  Spiritually and mentally inspiring! A book tha...  12 16, 2012
# 1  This is one my must have books. It is a master...  12 11, 2003
# 2  This book provides a reflection that you can a...  01 18, 2014
# 3  I first read THE PROPHET in college back in th...  09 27, 2011
# 4  A timeless classic.  It is a very demanding an...   10 7, 2002
#
#               reviewerID                                     reviewerName  \
# 0  A10000012B7CGYKOMPQ4L                                             Adam
# 1         A2S166WSCFIFP5  adead_poet@hotmail.com "adead_poet@hotmail.com"
# 2         A1BM81XB4QHOA3                      Ahoro Blethends "Seriously"
# ...

# %%
df_count.head()
# Out:
#                        helpfulVotes  totalVotes  asin
# reviewerID
# A03433312WBY334SUIKK8             0           0     1
# A04248682NPVFASKSXTAD             0           0     1
# A04816858XKO02H7BRNX              1           1     1
# A05059033JWCACJUK57F2             0           1     1
# A065405511YBV9PD987CA             1           1     1

# %%
df.index = df.asin

# %%
df.head()
# Out:
#             Unnamed: 0        asin helpful  overall  \
# asin
# 000100039X           0  000100039X  [0, 0]      5.0
# 000100039X           1  000100039X  [0, 2]      5.0
# 000100039X           2  000100039X  [0, 0]      5.0
# 000100039X           3  000100039X  [0, 0]      5.0
# 000100039X           4  000100039X  [7, 9]      5.0
#
#                                                    reviewText   reviewTime  \
# asin
# 000100039X  Spiritually and mentally inspiring! A book tha...  12 16, 2012
# 000100039X  This is one my must have books. It is a master...  12 11, 2003
# 000100039X  This book provides a reflection that you can a...  01 18, 2014
# 000100039X  I first read THE PROPHET in college back in th...  09 27, 2011
# 000100039X  A timeless classic.  It is a very demanding an...   10 7, 2002
#
#                        reviewerID  \
# asin
# 000100039X  A10000012B7CGYKOMPQ4L
# 000100039X         A2S166WSCFIFP5
# 000100039X         A1BM81XB4QHOA3
# 000100039X         A1MOSTXNIO5MPJ
# ...

# %%
del df['Unnamed: 0']

# %%
df.head()
# Out:
#                   asin helpful  overall  \
# asin
# 000100039X  000100039X  [0, 0]      5.0
# 000100039X  000100039X  [0, 2]      5.0
# 000100039X  000100039X  [0, 0]      5.0
# 000100039X  000100039X  [0, 0]      5.0
# 000100039X  000100039X  [7, 9]      5.0
#
#                                                    reviewText   reviewTime  \
# asin
# 000100039X  Spiritually and mentally inspiring! A book tha...  12 16, 2012
# 000100039X  This is one my must have books. It is a master...  12 11, 2003
# 000100039X  This book provides a reflection that you can a...  01 18, 2014
# 000100039X  I first read THE PROPHET in college back in th...  09 27, 2011
# 000100039X  A timeless classic.  It is a very demanding an...   10 7, 2002
#
#                        reviewerID  \
# asin
# 000100039X  A10000012B7CGYKOMPQ4L
# 000100039X         A2S166WSCFIFP5
# 000100039X         A1BM81XB4QHOA3
# 000100039X         A1MOSTXNIO5MPJ
# 000100039X         A2XQ5LZHTD4AFT
#
# ...

# %%
del df['asin']

# %%
df.set_index('reviewerID', append = True)
# Out:
#                                    helpful  overall  \
# asin       reviewerID
# 000100039X A10000012B7CGYKOMPQ4L    [0, 0]      5.0
#            A2S166WSCFIFP5           [0, 2]      5.0
#            A1BM81XB4QHOA3           [0, 0]      5.0
#            A1MOSTXNIO5MPJ           [0, 0]      5.0
#            A2XQ5LZHTD4AFT           [7, 9]      5.0
#            A3V1MKC2BVWY48           [0, 0]      5.0
#            A12387207U8U24           [0, 0]      5.0
#            A29TRDMK51GKZR           [0, 0]      5.0
#            A3FI0744PG1WYG           [0, 0]      5.0
#            A2LBBQHYLEHM7P           [0, 0]      5.0
#            A1340OFLZBW5NG           [0, 0]      5.0
#            A2KU9IU07LOJS1           [0, 0]      5.0
#            A2WVHIRDMLM82E           [0, 0]      5.0
#            A2I35JB67U20C0           [0, 0]      5.0
#            A19N3FCQCLJYUA           [1, 1]      5.0
#            A3FFNE1DR5SI1W           [1, 1]      5.0
#            A1TT4CY55WLHAR           [0, 0]      5.0
# ...

# %%
df.swaplevel('asin','reviewerID',axis=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-18b0e8898854> in <module>()
# ----> 1 df.swaplevel('asin','reviewerID',axis=0)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in swaplevel(self, i, j, axis)
#    3837         axis = self._get_axis_number(axis)
#    3838         if axis == 0:
# -> 3839             result.index = result.index.swaplevel(i, j)
#    3840         else:
#    3841             result.columns = result.columns.swaplevel(i, j)
#
# AttributeError: 'Index' object has no attribute 'swaplevel'
